# %%
import boto3
import os
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from email.mime.application import MIMEApplication
from dotenv import load_dotenv
import pandas as pd
import random
from datetime import datetime

# %%
load_dotenv()
AWS_SES_REGION = os.getenv("AWS_SES_REGION")
AWS_SECRET_ACCESS_KEY = os.getenv("AWS_SECRET_ACCESS_KEY")
AWS_ACCESS_KEY_ID = os.getenv("AWS_ACCESS_KEY_ID")

# %%
def send_ryan_email(name, email, sender, subject):
# ---- Configuration ----
  SENDER = sender
  RECIPIENT = email
  SUBJECT = subject
  NAME= name.split(" ")[0]
  HTML_BODY = f"""
  <html>
  <head>
    <meta charset="UTF-8">
    <title>AML Support Email</title>
  </head>
  <body style="font-family: Arial, sans-serif; font-size: 16px; color: #333;">
    <p>Hi {NAME},</p>

    <p>My name is Ryan, and I’m an engineering grad at the University of Waterloo working on a solution to simplify anti-money laundering (AML) compliance.</p>

    <p>If setting up your compliance regime or dealing with FINTRAC reporting has been a challenge, I’d love to connect for a quick 30-minute chat to see how my team might be able to support your efforts. If there’s someone else in your organization who’s more directly involved with AML or FINTRAC compliance, I’d greatly appreciate an introduction.</p>

    <p>In the 30 minutes, you'll save countless hours doing manual research or working with other consultants.</p>

    <p>Let me know if you're open to a brief conversation—I’m happy to find a time that works for you.</p>

    <p>Best regards,</p>

    <p>Ryan</p>

    <p>
      <a href="https://calendar.app.google/aVSZwkejuWqMG3Cm8" target="_blank" style="color: #1a73e8;">Schedule a meeting</a>
    </p>
  </body>
  </html>
  """
  TEXT_BODY = "Hello!\nThis is a test email with an attachment, sent using Amazon SES."

  # ---- Build Email ----
  msg = MIMEMultipart('mixed')
  msg['Subject'] = SUBJECT
  msg['From'] = SENDER
  msg['To'] = RECIPIENT

  # Alternative part (text + HTML)
  msg_body = MIMEMultipart('alternative')
  msg_body.attach(MIMEText(TEXT_BODY, 'plain'))
  msg_body.attach(MIMEText(HTML_BODY, 'html'))

  # Attach the body to the main message
  msg.attach(msg_body)

  # ---- Attachment ----
  """ 
  ATTACHMENT_PATH = "CRM.xlsx"  # Change this to your file path

     with open(ATTACHMENT_PATH, 'rb') as f:
      part = MIMEApplication(f.read())
      part.add_header('Content-Disposition', 'attachment', filename=os.path.basename(ATTACHMENT_PATH))
      msg.attach(part) """

  # ---- Send via SES ----
  client = boto3.client('ses', region_name=AWS_SES_REGION)

  response = client.send_raw_email(
      Source=SENDER,
      Destinations=[RECIPIENT],
      RawMessage={
          'Data': msg.as_string()
      }
  )

  message_id = response["MessageId"]

  print("Email sent! Message ID:", message_id)
  return message_id



def bulk_send_ryan_email(df:pd.DataFrame):
  subjects = [
    "Need Help Setting up a FINTRAC Compliance Regime?",
    "Toronto New Grad Founder Reaching Out on AML"
    ]

  senders = [
      "r2mark@uwaterloo.ca",
      "ryanymark@gmail.com",
      "ryan@quantoflow.com"
  ]

  subject = random.choice(subjects)
  sender = random.choice(senders)

  logs = []
  for index, row in df.iterrows():
    message_id = send_ryan_email(row["Name"], row["Emails"], sender, subject)
    logs.append({
      "timestamp":datetime.now(),
      "id":message_id, 
      "sender":sender,
      "subject":subject,
      "name":row["Name"],
      "recipient":row["Emails"]
    })

  logs_df = pd.DataFrame(logs)
  logs_df.to_csv(f"./log-{datetime.today().strftime('%Y-%m-%d')}.csv", index=False)

# %%
def send_michael_email(name, email, sender, subject):
# ---- Configuration ----
  SENDER = sender
  RECIPIENT = email
  SUBJECT = subject
  NAME= name.split(" ")[0]
  HTML_BODY = f"""
  <html>
  <head>
    <meta charset="UTF-8">
    <title>AML Support Email</title>
  </head>
  <body style="font-family: Arial, sans-serif; font-size: 16px; color: #333;">
    <p>Hi {NAME},</p>

    <p>My name is Michael, and I’m a recent grad from the University of Toronto working on a solution to simplify anti-money laundering (AML) compliance.</p>

    <p>If setting up your compliance regime or dealing with FINTRAC reporting has been a challenge, I’d love to connect for a quick 30-minute chat to see how my team might be able to support your efforts. If there’s someone else in your organization who’s more directly involved with AML or FINTRAC compliance, I’d greatly appreciate an introduction.</p>

    <p>In the 30 minutes, you'll save countless hours doing manual research or working with other consultants.</p>

    <p>Let me know if you're open to a brief conversation—I’m happy to find a time that works for you.</p>

    <p>Best regards,</p>

    <p>Michael</p>
    <p>Cofounder and CEO, Quantoflow.com</p>
    <a href="https://www.linkedin.com/in/nicetomeetyu/" target="_blank" style="color: #1a73e8;">LinkedIn</a>

    <p>
      <a href="https://calendly.com/nicetomeetyu/meeting" target="_blank" style="color: #1a73e8;">Schedule a meeting</a>
    </p>
  </body>
  </html>
  """
  TEXT_BODY = "Hello!\nThis is a test email with an attachment, sent using Amazon SES."

  # ---- Build Email ----
  msg = MIMEMultipart('mixed')
  msg['Subject'] = SUBJECT
  msg['From'] = SENDER
  msg['To'] = RECIPIENT

  # Alternative part (text + HTML)
  msg_body = MIMEMultipart('alternative')
  msg_body.attach(MIMEText(TEXT_BODY, 'plain'))
  msg_body.attach(MIMEText(HTML_BODY, 'html'))

  # Attach the body to the main message
  msg.attach(msg_body)

  # ---- Attachment ----
  """ 
  ATTACHMENT_PATH = "CRM.xlsx"  # Change this to your file path

     with open(ATTACHMENT_PATH, 'rb') as f:
      part = MIMEApplication(f.read())
      part.add_header('Content-Disposition', 'attachment', filename=os.path.basename(ATTACHMENT_PATH))
      msg.attach(part) """

  # ---- Send via SES ----
  client = boto3.client('ses', region_name=AWS_SES_REGION)

  response = client.send_raw_email(
      Source=SENDER,
      Destinations=[RECIPIENT],
      RawMessage={
          'Data': msg.as_string()
      }
  )

  message_id = response["MessageId"]

  print("Email sent! Message ID:", message_id)
  return message_id



def bulk_send_michael_email(df:pd.DataFrame):
  subjects = [
    "Need Help Setting up a FINTRAC Compliance Regime?",
    "Toronto New Grad Founder Reaching Out for AML Compliance"
    ]

  senders = [
      "michael@quantoflow.com",
      "nicetomeet.yu@alumni.utoronto.ca",
  ]

  subject = random.choice(subjects)
  sender = random.choice(senders)

  logs = []
  for index, row in df.iterrows():
    message_id = send_michael_email(row["Name"], row["Emails"], sender, subject)
    logs.append({
      "timestamp":datetime.now(),
      "id":message_id, 
      "sender":sender,
      "subject":subject,
      "name":row["Name"],
      "recipient":row["Emails"]
    })

  logs_df = pd.DataFrame(logs)
  logs_df.to_csv(f"./log-{datetime.today().strftime('%Y-%m-%d')}.csv", index=False)

# %%
canadian_leads = pd.read_excel("./CRM.xlsx", sheet_name="Apr 10 (to send)")
canadian_leads.head()
# Out:
#                 Name                   Job title                 Company  \
# 0        Neil Lochem     Chief Financial Officer  Performance Auto Group
# 1       Joann Squire  Financial Services Manager       Leggat Auto Group
# 2      Jeanne Lajoie  Financial Services Manager  Performance Auto Group
# 3   Christopher Alto     Chief Financial Officer     Pinnacle Auto Group
# 4  Candis Cunningham  Financial Services Manager       Morrey Auto Group
#
#                           Emails         Phone numbers  Actions  \
# 0  neil.vanlochem@performance.ca  Request phone number      NaN
# 1              jsquire@leggat.ca  Request phone number      NaN
# 2   jeanne.lajoie@performance.ca  Request phone number      NaN
# 3             alto@mbwinnipeg.ca  Request phone number      NaN
# 4          candis@morreyauto.com  Request phone number      NaN
#
#                                                Links Location  \
# 0  http://www.linkedin.com/in/neil-van-lochem-cpa...     N/A0
# 1   http://www.linkedin.com/in/joann-squire-a80a6251     N/A0
# 2  http://www.linkedin.com/in/jeanne-lajoie-85b74070     N/A0
# 3  http://www.linkedin.com/in/christopher-alto-cp...     N/A0
# 4  http://www.linkedin.com/in/candis-cunningham-0...     N/A0
#
#   Company · Number of employees Company · Industries  \
# 0               Grimsby, Canada                  620
# 1                Milton, Canada                  110
# 2            Huntsville, Canada                  620
# 3              Winnipeg, Canada                    3
# 4             Coquitlam, Canada                   81
#
#                     Company · Keywords
# 0                           Automotive
# 1                           Automotive
# 2                           Automotive
# 3  Electrical/electronic Manufacturing
# 4                           Automotive

# %%
canadian_leads_cleaned = canadian_leads[canadian_leads["Emails"]!="No email"]
canadian_leads_cleaned["Emails"] = canadian_leads_cleaned["Emails"].apply(lambda x: x.split(" ")[0])
print(canadian_leads.shape)
print(canadian_leads_cleaned.shape)
# Out:
# (295, 11)
# (271, 11)
# C:\Users\nicet\AppData\Local\Temp\ipykernel_3960\2740240871.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   canadian_leads_cleaned["Emails"] = canadian_leads_cleaned["Emails"].apply(lambda x: x.split(" ")[0])

# %%
canadian_leads_cleaned.iloc[10]
# Out:
# Name                                                     Aly Ladak
# Job title                               Financial Services Manager
# Company                                          Morrey Auto Group
# Emails                                          aly@morreyauto.com
# Phone numbers                                 Request phone number
# Actions                                                        NaN
# Links                            http://www.linkedin.com/in/aladak
# Location                                                      N/A0
# Company · Number of employees                    Vancouver, Canada
# Company · Industries                                            81
# Company · Keywords                                      Automotive
# Name: 10, dtype: object

# %%
test_df = pd.DataFrame([{
    "Name":"Michael Yu",
    "Emails":"michael@quantoflow.com"
},
{
    "Name":"Ryan Mark",
    "Emails":"ryanymark@gmail.com"
}]
)

# %%
test_df.head()
# Out:
#          Name                  Emails
# 0  Michael Yu  michael@quantoflow.com
# 1   Ryan Mark     ryanymark@gmail.com

# %%
#DANGER ZONE: Uncomment to send bulk emails
#bulk_send_michael_email(canadian_leads_cleaned)
# Out:
# Email sent! Message ID: 010f019625c379c7-84607677-0118-4f63-9c65-f18f83fbe83f-000000
# Email sent! Message ID: 010f019625c37b4f-ed58016a-b5df-4299-9aec-511ef8270763-000000
# Email sent! Message ID: 010f019625c37c9f-917ae8e6-214f-47c8-8e4c-31c24e1da134-000000
# Email sent! Message ID: 010f019625c37e1d-904f579f-3880-4d57-8ff8-8dc167a75660-000000
# Email sent! Message ID: 010f019625c37f99-44fd9800-c10a-4a3a-93a5-495d9e9a4434-000000
# Email sent! Message ID: 010f019625c3816d-7a915a22-0ac1-404d-b7fd-7a6dfc588634-000000
# Email sent! Message ID: 010f019625c382d5-c4b1c288-6035-4d0a-b83f-1755bcaf7609-000000
# Email sent! Message ID: 010f019625c3843d-6f2c5031-8d07-47ae-a787-2d091df82e97-000000
# Email sent! Message ID: 010f019625c385a3-a15c035c-127a-4b75-a1e2-e1df1edd8a0d-000000
# Email sent! Message ID: 010f019625c38726-15bc5e7c-54cd-49b6-a222-687df9e82dd2-000000
# Email sent! Message ID: 010f019625c38873-087b8ab3-dd66-4a19-afa2-2c42caad9367-000000
# Email sent! Message ID: 010f019625c389f6-3a478b85-1cbf-47c1-ab55-2b091c9fea6e-000000
# Email sent! Message ID: 010f019625c38b59-2f63f1e8-898a-4eb6-9656-2234bda590cf-000000
# Email sent! Message ID: 010f019625c38caf-7ea4bada-a1b2-4d4c-9681-3cde13ee789e-000000
# Email sent! Message ID: 010f019625c38e27-b7c54088-0521-407b-8f76-f24a5d683a34-000000
# Email sent! Message ID: 010f019625c38f75-21e65d15-ab72-4d8f-989c-09afb05b5618-000000
# Email sent! Message ID: 010f019625c390c6-ab26c7b8-45cc-44ec-9cb8-9cd38d283f20-000000
# Email sent! Message ID: 010f019625c39217-6b595f6b-aa65-4d0c-9c7b-eee278cda727-000000
# Email sent! Message ID: 010f019625c3935e-8afe9314-6c33-4a4c-bfa6-4900472fa2fe-000000
# Email sent! Message ID: 010f019625c394b7-52ef481f-7168-4191-9dc4-de4d5d68c17a-000000
# Email sent! Message ID: 010f019625c39617-7b97a367-a7b6-46b3-8af6-10e08b29fdad-000000
# Email sent! Message ID: 010f019625c3976a-70be9ee3-2996-46a1-9c4e-dad87611812d-000000
# Email sent! Message ID: 010f019625c398f3-d96c069f-b3a5-419c-97c1-936f438752e9-000000
# Email sent! Message ID: 010f019625c39a52-ecae22e5-39eb-4591-9047-d5f3240ed5f0-000000
# Email sent! Message ID: 010f019625c39bcb-452c057e-4617-48c1-8edc-7653381d9671-000000
# Email sent! Message ID: 010f019625c39d32-a72ef10c-99e7-482c-8952-1f7c9fa5db82-000000
# Email sent! Message ID: 010f019625c39e8e-c3b3ddec-478b-4dc1-808e-a4b84d6b30bb-000000
# Email sent! Message ID: 010f019625c39fe5-4e852d47-988f-456f-b531-07a724cd684a-000000
# Email sent! Message ID: 010f019625c3a154-a37178ff-2b75-49ce-9895-c293289326e3-000000
# Email sent! Message ID: 010f019625c3a2e7-1ca84570-ac20-4842-a1db-3af543cc65c5-000000
# Email sent! Message ID: 010f019625c3a446-05c09385-e798-40e0-bad0-3b3ffebc12a6-000000
# Email sent! Message ID: 010f019625c3a5b2-022b68a8-105e-49b4-94e1-20ee9eea7583-000000
# Email sent! Message ID: 010f019625c3a70d-4682044b-42f5-4f35-bb36-4bc986db4721-000000
# Email sent! Message ID: 010f019625c3a857-c7a86018-952c-4b29-9628-56c23d89f6c0-000000
# Email sent! Message ID: 010f019625c3a9ad-586d013b-7d6f-4325-aaa3-0e3f988ec958-000000
# Email sent! Message ID: 010f019625c3ab0f-d449d7bd-e4ee-43b2-a99c-3811f67f44c6-000000
# Email sent! Message ID: 010f019625c3ac5d-9b8ee16f-1525-46b7-9426-bb3e490c3dd5-000000
# Email sent! Message ID: 010f019625c3adb5-f7432eaf-9bc5-4ec0-94e8-72de9e0a788a-000000
# Email sent! Message ID: 010f019625c3af13-aa3780a0-8171-4f0e-9bbc-eace4c6bb6e7-000000
# Email sent! Message ID: 010f019625c3b07e-59df27d6-fbed-4b6b-8f84-1127e1805de1-000000
# Email sent! Message ID: 010f019625c3b212-3ff65f0f-799c-4dfc-b444-72ee94895d8a-000000
# Email sent! Message ID: 010f019625c3b36c-c32174b7-7fa9-41a1-a677-09e7e5468b89-000000
# Email sent! Message ID: 010f019625c3b4c2-9a8a468f-2abd-451f-90b6-67c2f43673fc-000000
# Email sent! Message ID: 010f019625c3b622-c3e899c8-dcfc-4f48-8c51-39949224e49f-000000
# Email sent! Message ID: 010f019625c3b77d-c8c6ad03-f7ff-49b6-8d9a-bf1783823936-000000
# Email sent! Message ID: 010f019625c3b8cd-dad77bec-459d-4d7d-bb31-6e2101f5708a-000000
# Email sent! Message ID: 010f019625c3ba25-1460ef02-3b17-4fe7-a8df-65b445f1cfbe-000000
# Email sent! Message ID: 010f019625c3bb8c-c43c0bf0-a8b3-437d-ab26-3a8787f96d56-000000
# Email sent! Message ID: 010f019625c3bd13-ef5f7f34-1bc7-46df-bb96-193c19b45550-000000
# Email sent! Message ID: 010f019625c3be83-63678bd4-9b40-405a-859c-568a64fc70d4-000000
# Email sent! Message ID: 010f019625c3bfdb-2914c448-627d-42ca-99c8-f8421bb5790b-000000
# Email sent! Message ID: 010f019625c3c14b-bb121a36-5dd1-4c49-91b3-b1326735abf5-000000
# Email sent! Message ID: 010f019625c3c296-dd82cf09-c322-47c8-8e90-930fe8247bec-000000
# Email sent! Message ID: 010f019625c3c3e2-74974194-2c23-4792-839f-7290c7b08a9f-000000
# Email sent! Message ID: 010f019625c3c527-2e8d5766-4d0f-4f6e-9dd7-7ee177046505-000000
# Email sent! Message ID: 010f019625c3c67e-8a68f241-b28f-4e1c-be6d-0fbd50363584-000000
# Email sent! Message ID: 010f019625c3c7de-98c73714-299a-481f-965b-3edf6aea0452-000000
# Email sent! Message ID: 010f019625c3c91a-d8d258c7-d953-497b-811f-47a9e93319b4-000000
# Email sent! Message ID: 010f019625c3ca82-9a8da1c0-7500-4e4c-a540-a657a46f0da5-000000
# Email sent! Message ID: 010f019625c3cbcf-37534966-fcb5-483e-ac27-cd2b57ce2a99-000000
# Email sent! Message ID: 010f019625c3cd16-87eeafa7-fa61-4a5f-ab80-385f0f80f846-000000
# Email sent! Message ID: 010f019625c3ce71-1bd11d93-42d6-4937-aad5-4fc26a369ca9-000000
# Email sent! Message ID: 010f019625c3cfca-f40bc009-332f-4443-bfab-8c9cad79f91f-000000
# Email sent! Message ID: 010f019625c3d12c-00e86189-a797-4df6-a2ee-913a0bd1b661-000000
# Email sent! Message ID: 010f019625c3d406-f2093233-5f19-4231-8ada-c7476b582d39-000000
# Email sent! Message ID: 010f019625c3d560-9c43216b-c5d7-48ce-b5a2-584c7b42d123-000000
# Email sent! Message ID: 010f019625c3d6a7-7f3efee0-58d5-487d-a405-fe9b2edbb169-000000
# Email sent! Message ID: 010f019625c3d7ea-237f0563-5ae7-434a-a1aa-f8f491dd11fc-000000
# Email sent! Message ID: 010f019625c3d943-13874c3c-4685-4705-b268-5107ba6a53aa-000000
# Email sent! Message ID: 010f019625c3da91-f4a405c7-4e69-4148-9e40-7ae070d8ded6-000000
# Email sent! Message ID: 010f019625c3dbde-41826867-c26a-4963-81d2-45488c27ec53-000000
# Email sent! Message ID: 010f019625c3dd27-ddfd544e-68ba-437f-99df-016211a3857d-000000
# Email sent! Message ID: 010f019625c3de86-1d216b99-ca39-42ae-9cf1-1fd420c554ca-000000
# Email sent! Message ID: 010f019625c3dfdd-ce4c8a5f-8c10-4cd2-9bf0-f1d52fa0f490-000000
# Email sent! Message ID: 010f019625c3e135-3a6cf4e5-1547-4cc4-b56e-02911b496158-000000
# Email sent! Message ID: 010f019625c3e26a-c8ce2821-2899-4006-b005-39d1089e6eca-000000
# Email sent! Message ID: 010f019625c3e3b2-23063c21-b9ec-496c-9c48-beda50084b62-000000
# Email sent! Message ID: 010f019625c3e4ff-6e83ce68-be82-487f-9c2a-8b685eb2ddc1-000000
# Email sent! Message ID: 010f019625c3e643-84da3b80-dad5-4eb8-b79f-149a4247c653-000000
# Email sent! Message ID: 010f019625c3e78d-05b84bee-eddf-4421-bd8b-04ffbd5439e7-000000
# Email sent! Message ID: 010f019625c3e8ef-77e79e66-b6e9-4e04-bc0e-5b7e48c7c04b-000000
# Email sent! Message ID: 010f019625c3ea4a-e24e1f01-e770-4aed-91fe-cf1183eeee7e-000000
# Email sent! Message ID: 010f019625c3eb8e-ed3a767d-76bb-4528-b6f0-82a37ce83077-000000
# Email sent! Message ID: 010f019625c3eceb-c83e3f98-5e9d-4e9d-816a-3b0feac3ebd2-000000
# Email sent! Message ID: 010f019625c3ee2f-31618dd4-1136-49be-827a-ea3d9b4fcded-000000
# Email sent! Message ID: 010f019625c3ef8e-5691764b-0926-4f93-b6bf-7b9743b6eefa-000000
# Email sent! Message ID: 010f019625c3f0e2-63a4edb4-f0b5-4b53-bc9d-e742c46a2fbc-000000
# Email sent! Message ID: 010f019625c3f230-c5441877-a872-466b-bcd8-5a5cef91e79c-000000
# Email sent! Message ID: 010f019625c3f375-9c1a18ec-2fea-46ac-903f-b5ac952154c6-000000
# Email sent! Message ID: 010f019625c3f4d3-85b53092-0e44-4e18-9fa3-39543bf6c202-000000
# Email sent! Message ID: 010f019625c3f63e-14d104eb-4b0f-46bb-bd6c-d53e8c4f95d9-000000
# Email sent! Message ID: 010f019625c3f792-49776798-ad1b-4f0f-9573-f7458642c6b8-000000
# Email sent! Message ID: 010f019625c3f8e2-db08c77a-3178-4963-a843-ba95564f70a2-000000
# Email sent! Message ID: 010f019625c3fa2d-09d7aea3-12e3-41fa-8b5d-2489a322dff2-000000
# Email sent! Message ID: 010f019625c3fb80-a9a25d3e-02d4-4d70-9e9d-f176b0992f39-000000
# Email sent! Message ID: 010f019625c3fd06-55152c5e-b28b-45fb-b3f8-a4a8fcf225a8-000000
# Email sent! Message ID: 010f019625c3fe4e-ce22e330-f949-4742-a1ec-c7818a184dab-000000
# Email sent! Message ID: 010f019625c3ff92-7ba45ecf-45f8-4ce4-8d9b-2fb140455f92-000000
# Email sent! Message ID: 010f019625c400de-b7dda61c-aad3-43ac-b41f-c5be8c5e2c4f-000000
# Email sent! Message ID: 010f019625c4022a-685c4bb1-7584-4fa3-949c-a3be558cc3e5-000000
# Email sent! Message ID: 010f019625c40387-e5a665b5-3306-48a5-83a2-5cee4ab0d928-000000
# Email sent! Message ID: 010f019625c40525-06610fdd-5197-42f4-87a6-ee10e04ce066-000000
# Email sent! Message ID: 010f019625c4069a-c2a06be4-05ff-4d35-8ce7-620bd09710a9-000000
# Email sent! Message ID: 010f019625c407f2-7901a3c3-c393-4f28-9451-12ec2411f7e2-000000
# Email sent! Message ID: 010f019625c4095a-604ce023-4323-4858-8c44-d90d739dbc81-000000
# Email sent! Message ID: 010f019625c40aa2-6219998b-e17f-45c7-83f9-416d8c383b9e-000000
# Email sent! Message ID: 010f019625c40bde-43215d7f-611b-443e-a8fe-7b7e88a4da63-000000
# Email sent! Message ID: 010f019625c40d3a-c11acc40-8110-4249-9729-e3514c1d8bd3-000000
# Email sent! Message ID: 010f019625c40e72-084253f6-ed18-4d64-86a8-754a2bcece7f-000000
# Email sent! Message ID: 010f019625c40fbf-dfbc3266-af9e-487b-a9e2-060bddced410-000000
# Email sent! Message ID: 010f019625c41109-33155e79-5ae5-42f5-af25-a4315f8a29bf-000000
# Email sent! Message ID: 010f019625c4126a-f8176be5-7e80-4b38-9f0d-e8660e693b80-000000
# Email sent! Message ID: 010f019625c413b7-2a73d449-b2c3-4a3c-ae72-6766822dafd3-000000
# Email sent! Message ID: 010f019625c4150f-4a845c6c-9146-4040-8a49-63853dd876ee-000000
# Email sent! Message ID: 010f019625c4164f-ab1e0cb0-5828-45f0-bdbe-621ec321a782-000000
# Email sent! Message ID: 010f019625c4179e-d128df82-18b1-49b3-b23e-ffa84b6f80b2-000000
# Email sent! Message ID: 010f019625c41907-c908c26d-2d69-4dcd-b050-f0576a2dea70-000000
# Email sent! Message ID: 010f019625c41a52-c0358341-6fea-49fc-b676-f07a30636cce-000000
# Email sent! Message ID: 010f019625c41b9e-26358808-eba4-420f-be7a-93ce96b979ce-000000
# Email sent! Message ID: 010f019625c41cfb-5feb3249-2f43-4483-8f90-a8997d403c0a-000000
# Email sent! Message ID: 010f019625c41e53-e86e4326-4806-4404-b338-ea9a4845d089-000000
# Email sent! Message ID: 010f019625c41fb4-aec7652b-e562-4508-a256-232e129947ff-000000
# Email sent! Message ID: 010f019625c4212f-ce06240f-db6b-4bf7-9fa3-3909e4421b92-000000
# Email sent! Message ID: 010f019625c4229e-bf645b22-17a1-4686-af41-16b67e3c3ce9-000000
# Email sent! Message ID: 010f019625c423ee-b01869a9-5260-4058-9f83-88bf86ac2e78-000000
# Email sent! Message ID: 010f019625c42550-b0bc2eba-b452-4658-ad25-1ddcbd214246-000000
# Email sent! Message ID: 010f019625c426bb-be5b5897-7186-4af4-b2a7-4d6235712c4f-000000
# Email sent! Message ID: 010f019625c42820-4a815f76-56e1-49dd-bf63-273cda2c9469-000000
# Email sent! Message ID: 010f019625c4297e-21fdd81e-a5ca-4219-b5a5-28d79954e8c0-000000
# Email sent! Message ID: 010f019625c42acc-d87b57b4-0551-457e-af47-cfd32632c695-000000
# Email sent! Message ID: 010f019625c42c2b-af2fb059-7b72-49d3-a4ee-b3db1ffe485f-000000
# Email sent! Message ID: 010f019625c42d7f-6bb9d31d-a147-4a03-bbf4-1c0bad5268f4-000000
# Email sent! Message ID: 010f019625c42ee6-5238baba-da24-4b17-924f-b02100c3556c-000000
# Email sent! Message ID: 010f019625c43042-5fd8bd7e-4f87-4ec7-9fcf-4497c0f2fa06-000000
# Email sent! Message ID: 010f019625c4319e-c2deac67-59f5-426c-9661-b53a7050530c-000000
# Email sent! Message ID: 010f019625c43325-5f8c3ee1-ac52-4882-b8db-23b4af39aaa4-000000
# Email sent! Message ID: 010f019625c43493-581d3f71-5a8c-4a8c-9a64-a671b9bbecfe-000000
# Email sent! Message ID: 010f019625c435f5-c0bcc3c3-4f29-48fb-a72a-7171d632f6f7-000000
# Email sent! Message ID: 010f019625c4374b-5a55cda7-c785-4ae7-bbbd-9ec0dd4b3ac7-000000
# Email sent! Message ID: 010f019625c438a2-35fb7b32-97d8-4b71-9d48-3b5216567ebb-000000
# Email sent! Message ID: 010f019625c439f8-ec3ea286-e4d9-4b5a-81a3-3a791388f61d-000000
# Email sent! Message ID: 010f019625c43b8e-1fabf15a-7ba0-4f25-b740-307ebf1b5524-000000
# Email sent! Message ID: 010f019625c43cf6-55e69944-88cc-4491-856d-44e45fe7c735-000000
# Email sent! Message ID: 010f019625c43e59-862fd6da-a79b-48c6-844b-593d4f216802-000000
# Email sent! Message ID: 010f019625c43fbe-b29e3d5b-30b4-47dd-8618-128ada052e6b-000000
# Email sent! Message ID: 010f019625c44116-31fccedd-10dd-45ee-871b-998e54cc5d25-000000
# Email sent! Message ID: 010f019625c4425f-925df3bd-1efb-4dd4-9f12-58ed31d2d058-000000
# Email sent! Message ID: 010f019625c443df-3a977ed5-7a7d-4ad5-9e86-7acf6013a965-000000
# Email sent! Message ID: 010f019625c4453a-3a638f46-8920-4d5e-a772-fe5be6dc4498-000000
# Email sent! Message ID: 010f019625c4468c-3cf99ebb-3e77-451a-9f23-c3d78c388293-000000
# Email sent! Message ID: 010f019625c447fa-05fac38b-57bb-4bbe-984c-879ddf1438c4-000000
# Email sent! Message ID: 010f019625c44946-4911cb21-b602-48df-a511-c22c08dc4c6c-000000
# Email sent! Message ID: 010f019625c44a96-21eed636-a3f9-4fb4-a8f1-e079b21ae0e8-000000
# Email sent! Message ID: 010f019625c44bee-c7c995f4-8824-43ad-8c1c-a080b1d6d24b-000000
# Email sent! Message ID: 010f019625c44d42-9806e56c-089b-468e-90cd-72c8d8c030c4-000000
# Email sent! Message ID: 010f019625c44ea6-afce6ce2-ae2b-4675-a199-ebac0f1751ee-000000
# Email sent! Message ID: 010f019625c45012-0d360008-e765-418c-9387-bf66ed5a61c9-000000
# Email sent! Message ID: 010f019625c4518a-c9041ce2-5109-4b2b-aac3-ce85ea4cda38-000000
# Email sent! Message ID: 010f019625c452e2-0d44dd33-0cf5-42af-8d8c-c18ba10a083d-000000
# Email sent! Message ID: 010f019625c45430-40914bed-df5f-4791-971a-072ade3ec45f-000000
# Email sent! Message ID: 010f019625c455a6-cf62a4cc-52ba-4bd9-9c8c-63ceafc6a3dd-000000
# Email sent! Message ID: 010f019625c45712-021c321e-a699-4252-87c3-b2a5a17ee1f2-000000
# Email sent! Message ID: 010f019625c45870-3762c345-fef8-4f08-b02c-54a6efa8f24a-000000
# Email sent! Message ID: 010f019625c459c3-2d3b471f-8269-4a22-b17d-16bcefb7fabe-000000
# Email sent! Message ID: 010f019625c45b1a-9c7d7205-7be4-48d8-973a-85c70cc5ea0e-000000
# Email sent! Message ID: 010f019625c45c8c-1c89872a-8a10-4a5b-992b-21cb951bf66b-000000
# Email sent! Message ID: 010f019625c45dda-46af4aec-9882-401f-b9a6-5abd21f418bd-000000
# Email sent! Message ID: 010f019625c45f42-fee4a064-1523-4bba-b9a3-4ba1774676e1-000000
# Email sent! Message ID: 010f019625c460ad-3a99d56d-51e7-46d9-80d1-086119f32962-000000
# Email sent! Message ID: 010f019625c46224-35287d32-dab7-4944-940a-52faf606c8a2-000000
# Email sent! Message ID: 010f019625c46392-9843bbe5-7a39-43aa-b2ba-1feebaa8479c-000000
# Email sent! Message ID: 010f019625c464fe-b5a1e25b-189e-410f-9229-1e93334ed0eb-000000
# Email sent! Message ID: 010f019625c4668e-c004e1bc-59d1-431b-8fcf-7dd06ab2cf7a-000000
# Email sent! Message ID: 010f019625c467db-16a3e6d0-fcd7-4d55-873e-ed6044aca2e1-000000
# Email sent! Message ID: 010f019625c46941-100150e0-ab8f-473b-9428-8fcf9d7de6f8-000000
# Email sent! Message ID: 010f019625c46aff-de0582ee-c18b-425f-80cb-92a403bf38c1-000000
# Email sent! Message ID: 010f019625c46c5a-33cf83df-c5dc-4cb9-b234-f8aecffb3d03-000000
# Email sent! Message ID: 010f019625c46db3-686fe8bd-2aa9-4750-aa09-a61dfeb44cda-000000
# Email sent! Message ID: 010f019625c46f0a-5f84c701-c936-4fb6-911c-3fdf7cbf3f45-000000
# Email sent! Message ID: 010f019625c4705d-4aaefb37-66d0-44b3-8dce-342a640e2f3a-000000
# Email sent! Message ID: 010f019625c471c1-33bce195-c323-4684-b311-aaf954160f33-000000
# Email sent! Message ID: 010f019625c47333-0fde9a80-3fab-4db7-b9d4-cdcb786a43e9-000000
# Email sent! Message ID: 010f019625c47482-4fecae70-ff43-4a18-8c79-c9dc1b7b93c7-000000
# Email sent! Message ID: 010f019625c475df-5841493b-795c-4e62-885f-bbc33ea276cf-000000
# Email sent! Message ID: 010f019625c4772a-6a72f5bc-dac5-4e6e-bb73-646e31bcb07b-000000
# Email sent! Message ID: 010f019625c47886-94fde15f-34d5-4d7c-af68-e855a67a54c8-000000
# Email sent! Message ID: 010f019625c479e5-966eb83f-0143-4492-947e-3242ff341dd5-000000
# Email sent! Message ID: 010f019625c47b49-bc31ec4e-fbe4-4386-8b1d-503e82313125-000000
# Email sent! Message ID: 010f019625c47ca2-bac5cf80-d21f-466e-b60c-e5348adf0447-000000
# Email sent! Message ID: 010f019625c47dec-7d286456-83f6-47ba-811c-1980fe719fac-000000
# Email sent! Message ID: 010f019625c47f66-c4cb5104-18ba-4d49-9ce2-d3ce4084cf89-000000
# Email sent! Message ID: 010f019625c480ba-9fda86f6-e88c-449f-9411-662245df6304-000000
# Email sent! Message ID: 010f019625c4820a-f877fa3d-bae8-4aaf-a119-57d5204ab6b8-000000
# Email sent! Message ID: 010f019625c4836c-8add07e1-b643-43f0-9353-af77c4257e56-000000
# Email sent! Message ID: 010f019625c484ba-c3c7a549-1642-4600-93e1-37fb8df00b17-000000
# Email sent! Message ID: 010f019625c48614-addd2e7f-cc69-4882-a34b-cae71342a1db-000000
# Email sent! Message ID: 010f019625c48769-05685c5a-bd8e-4cd7-87c5-611f661a905b-000000
# Email sent! Message ID: 010f019625c488d2-1b9b8cd2-639d-4b05-9d09-b5914628d94f-000000
# Email sent! Message ID: 010f019625c48a2b-e5ca202b-d885-415a-b8f1-2a70b75cf245-000000
# Email sent! Message ID: 010f019625c48b9e-ca7bdc0a-46f4-4d87-9d51-8447a40bce52-000000
# Email sent! Message ID: 010f019625c48d02-ad555d2d-351d-46bc-ba18-ea29601a9cb1-000000
# Email sent! Message ID: 010f019625c48e5c-31e22e70-6546-44aa-a6e6-38c2840b2cd8-000000
# Email sent! Message ID: 010f019625c48fa6-bacf2333-34d1-477d-b06d-53a45efccf2e-000000
# Email sent! Message ID: 010f019625c4910b-1f7bacb0-da51-41cd-ae6d-5a0d22f6988e-000000
# Email sent! Message ID: 010f019625c4925f-82a3ffee-db3f-4b28-aca9-dc3f514545e2-000000
# Email sent! Message ID: 010f019625c49436-97b0d7c0-19b1-47f7-aae6-1f4fa09eb977-000000
# Email sent! Message ID: 010f019625c495a1-13a70938-8b3e-47ee-8d62-bb4a9d326b05-000000
# Email sent! Message ID: 010f019625c496f5-9953e3be-419a-4ece-9d6c-5cfdc523f2fb-000000
# Email sent! Message ID: 010f019625c49842-d4303843-7316-40fc-88a9-63447168567b-000000
# Email sent! Message ID: 010f019625c4999b-2168352e-d365-403a-b856-aa4d0eaf5e13-000000
# Email sent! Message ID: 010f019625c49afd-efe506da-71db-4860-890d-13934816c9ad-000000
# Email sent! Message ID: 010f019625c49c55-e3f9e3ef-78b5-4cd1-bab9-20af56c9b849-000000
# Email sent! Message ID: 010f019625c49daa-7ede71a2-8c66-46c6-b103-b3a515d3ea86-000000
# Email sent! Message ID: 010f019625c49f02-6bc1a758-60bb-4f45-9c01-6e0b23a16dac-000000
# Email sent! Message ID: 010f019625c4a07d-170d4247-66a3-45b4-bfbf-ab7faa9ec701-000000
# Email sent! Message ID: 010f019625c4a1c7-21dc4e6c-e933-4c8b-86f8-005bcff16260-000000
# Email sent! Message ID: 010f019625c4a331-12dc63ea-ac32-48b4-8842-6872785f176a-000000
# Email sent! Message ID: 010f019625c4a479-a9adccc1-a806-4190-9ec5-a4a6bbf898c1-000000
# Email sent! Message ID: 010f019625c4a5e1-75589829-7206-4b38-9b8f-d105ad53a0db-000000
# Email sent! Message ID: 010f019625c4a738-26e72307-481b-4c09-8ce9-f959aad5038d-000000
# Email sent! Message ID: 010f019625c4a888-054a5964-d42b-4d93-996d-e6dce63159ef-000000
# Email sent! Message ID: 010f019625c4a9d5-352ba5bd-293a-4543-afc2-73a55538659c-000000
# Email sent! Message ID: 010f019625c4ab28-6e0fe6a1-feff-483b-ad27-7694c018945c-000000
# Email sent! Message ID: 010f019625c4ac86-43a7ec92-1243-4b90-a6ac-ca6a81e13e50-000000
# Email sent! Message ID: 010f019625c4add6-83751339-5793-4a85-95f8-6495fc552a39-000000
# Email sent! Message ID: 010f019625c4af2c-60c0f014-245a-4c07-88de-86630d6dc929-000000
# Email sent! Message ID: 010f019625c4b0ab-9c89dbc5-93ec-4699-811b-12e7988efe19-000000
# Email sent! Message ID: 010f019625c4b22a-0b9989a9-8650-4ee3-87cc-245a3af4c17a-000000
# Email sent! Message ID: 010f019625c4b3a7-65ae000d-5b6d-45e5-9126-928bb912c401-000000
# Email sent! Message ID: 010f019625c4b51a-d1fee80b-ec84-4004-8a98-67871c381d53-000000
# Email sent! Message ID: 010f019625c4b67e-5ed46912-b801-49ae-81e7-a2b4830a5323-000000
# Email sent! Message ID: 010f019625c4b7e0-4d8706db-7d61-4cd2-b695-be80799cabd1-000000
# Email sent! Message ID: 010f019625c4b947-5b67497b-02c4-4133-86ba-785e2f643c17-000000
# Email sent! Message ID: 010f019625c4baab-8842ec5d-c45f-44b3-be90-710c1694152b-000000
# Email sent! Message ID: 010f019625c4bc21-616aaa4c-1601-477f-8062-6d1330770caa-000000
# Email sent! Message ID: 010f019625c4bda3-8f3f164f-85ea-4290-a9d8-280d600d284c-000000
# Email sent! Message ID: 010f019625c4bf06-75f0629f-10ee-4793-a798-280b02c4816e-000000
# Email sent! Message ID: 010f019625c4c056-f82a8d49-fe4d-4802-9d6c-e2eb1b057f98-000000
# Email sent! Message ID: 010f019625c4c1ac-b9b7fc96-f2b0-4b61-a1f9-2f078b312ca4-000000
# Email sent! Message ID: 010f019625c4c30a-2096580b-21ec-4ad4-ac72-e64dd2e1f17d-000000
# Email sent! Message ID: 010f019625c4c452-0c192713-328c-49a5-9b90-bd37eb1fee54-000000
# Email sent! Message ID: 010f019625c4c5aa-f0afc4b7-6160-40c0-bebf-a18ae3ec3b29-000000
# Email sent! Message ID: 010f019625c4c712-a91ae039-dad2-45fe-ba88-61dc15e8173c-000000
# Email sent! Message ID: 010f019625c4c871-3fdacc0b-f2d1-48dc-aa48-dead0d03e9f2-000000
# Email sent! Message ID: 010f019625c4c9db-9347ba92-0bdd-4fd4-8741-d7d54c74cee3-000000
# Email sent! Message ID: 010f019625c4cb2a-f1b50fd8-efc2-409b-86f0-20335bc4598b-000000
# Email sent! Message ID: 010f019625c4cc87-2f4fd7f0-8cd1-412f-8156-829606f96742-000000
# Email sent! Message ID: 010f019625c4cddf-b4078b23-5887-4769-9c50-8b811ba5c235-000000
# Email sent! Message ID: 010f019625c4cf2c-807cbddb-47b3-4544-a14e-124dc8802124-000000
# Email sent! Message ID: 010f019625c4d095-92574d08-4abd-4d7c-895e-b3054cabea60-000000
# Email sent! Message ID: 010f019625c4d1ff-36103528-e7ff-42e8-8ada-e596a2135122-000000
# Email sent! Message ID: 010f019625c4d351-2c077346-4f39-4e4c-bb95-343e4dc31a30-000000
# Email sent! Message ID: 010f019625c4d4a9-7b9432d2-cf24-44c2-9657-bae2b18bf893-000000
# Email sent! Message ID: 010f019625c4d5fb-0effdcba-297b-49e0-95fc-20e9f514d538-000000
# Email sent! Message ID: 010f019625c4d757-93062911-25c0-48d7-9c64-eb712158ce26-000000
# Email sent! Message ID: 010f019625c4d8be-d7e53bbf-9174-4bb1-a71a-515aca470a00-000000
# Email sent! Message ID: 010f019625c4da24-01561218-4d53-4dcc-8a64-eb2a1f6a4f70-000000
# Email sent! Message ID: 010f019625c4db80-7b010f7f-2844-456e-a94f-2160d0eead00-000000
# Email sent! Message ID: 010f019625c4dce9-f7bf2e06-7dcf-4a39-92d1-e6d3ea87c57e-000000
# Email sent! Message ID: 010f019625c4de76-6c49e4ea-111e-4dfa-a5e3-2b7e6cd28a08-000000
# Email sent! Message ID: 010f019625c4dfe4-ddfa8dde-a4fd-44ec-8168-8a807cea1999-000000
